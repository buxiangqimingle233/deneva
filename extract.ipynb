# %%
import xml.etree.ElementTree as ET

# XML content
xml_content = """
<rspec xmlns="http://www.geni.net/resources/rspec/3" xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" xmlns:tour="http://www.protogeni.net/resources/rspec/ext/apt-tour/1" xmlns:jacks="http://www.protogeni.net/resources/rspec/ext/jacks/1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.geni.net/resources/rspec/3    http://www.geni.net/resources/rspec/3/request.xsd" type="request">
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-0" exclusive="true" component_manager_id="urn:publicid:IDN+cloudlab.umass.edu+authority+cm" component_id="urn:publicid:IDN+cloudlab.umass.edu+node+pc71" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73869">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+emulab.net+image+emulab-ops//UBUNTU18-64-STD"/>
    </sliver_type>
    <hardware_type name="rs620"/>
    <interface client_id="node-0:interface-0" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc71:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73872" mac_address="000f5322e170">
      <ip address="10.10.1.1" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="pc71.cloudlab.umass.edu" port="22" username="bxqml233"/>
      <emulab:console server="boss.cloudlab.umass.edu"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="echo 'y' | sudo mkfs.ext4 /dev/nvme1n1"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="apt-get install -y cmake git python3-pip"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="pc71" hardware_type="rs620"/>
    <host name="node-0.ExpDevena.ds22-PG0.cloudlab.umass.edu" ipv4="198.22.255.82"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-1" exclusive="true" component_manager_id="urn:publicid:IDN+cloudlab.umass.edu+authority+cm" component_id="urn:publicid:IDN+cloudlab.umass.edu+node+pc82" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73863">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+emulab.net+image+emulab-ops//UBUNTU18-64-STD"/>
    </sliver_type>
    <hardware_type name="rs620"/>
    <interface client_id="node-1:interface-1" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc82:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73873" mac_address="000f53333560">
      <ip address="10.10.1.2" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="pc82.cloudlab.umass.edu" port="22" username="bxqml233"/>
      <emulab:console server="boss.cloudlab.umass.edu"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="echo 'y' | sudo mkfs.ext4 /dev/nvme1n1"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="apt-get install -y cmake git python3-pip"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="pc82" hardware_type="rs620"/>
    <host name="node-1.ExpDevena.ds22-PG0.cloudlab.umass.edu" ipv4="198.22.255.93"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-2" exclusive="true" component_manager_id="urn:publicid:IDN+cloudlab.umass.edu+authority+cm" component_id="urn:publicid:IDN+cloudlab.umass.edu+node+pc66" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73867">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+emulab.net+image+emulab-ops//UBUNTU18-64-STD"/>
    </sliver_type>
    <hardware_type name="rs620"/>
    <interface client_id="node-2:interface-2" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc66:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73874" mac_address="000f532284e0">
      <ip address="10.10.1.3" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="pc66.cloudlab.umass.edu" port="22" username="bxqml233"/>
      <emulab:console server="boss.cloudlab.umass.edu"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="echo 'y' | sudo mkfs.ext4 /dev/nvme1n1"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="apt-get install -y cmake git python3-pip"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="pc66" hardware_type="rs620"/>
    <host name="node-2.ExpDevena.ds22-PG0.cloudlab.umass.edu" ipv4="198.22.255.77"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-3" exclusive="true" component_manager_id="urn:publicid:IDN+cloudlab.umass.edu+authority+cm" component_id="urn:publicid:IDN+cloudlab.umass.edu+node+pc64" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73862">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+emulab.net+image+emulab-ops//UBUNTU18-64-STD"/>
    </sliver_type>
    <hardware_type name="rs620"/>
    <interface client_id="node-3:interface-3" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc64:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73875" mac_address="000f530df740">
      <ip address="10.10.1.4" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="pc64.cloudlab.umass.edu" port="22" username="bxqml233"/>
      <emulab:console server="boss.cloudlab.umass.edu"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="echo 'y' | sudo mkfs.ext4 /dev/nvme1n1"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="apt-get install -y cmake git python3-pip"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="pc64" hardware_type="rs620"/>
    <host name="node-3.ExpDevena.ds22-PG0.cloudlab.umass.edu" ipv4="198.22.255.75"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-4" exclusive="true" component_manager_id="urn:publicid:IDN+cloudlab.umass.edu+authority+cm" component_id="urn:publicid:IDN+cloudlab.umass.edu+node+pc70" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73864">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+emulab.net+image+emulab-ops//UBUNTU18-64-STD"/>
    </sliver_type>
    <hardware_type name="rs620"/>
    <interface client_id="node-4:interface-4" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc70:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73876" mac_address="000f53229410">
      <ip address="10.10.1.5" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="pc70.cloudlab.umass.edu" port="22" username="bxqml233"/>
      <emulab:console server="boss.cloudlab.umass.edu"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="echo 'y' | sudo mkfs.ext4 /dev/nvme1n1"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="apt-get install -y cmake git python3-pip"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="pc70" hardware_type="rs620"/>
    <host name="node-4.ExpDevena.ds22-PG0.cloudlab.umass.edu" ipv4="198.22.255.81"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-5" exclusive="true" component_manager_id="urn:publicid:IDN+cloudlab.umass.edu+authority+cm" component_id="urn:publicid:IDN+cloudlab.umass.edu+node+pc69" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73865">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+emulab.net+image+emulab-ops//UBUNTU18-64-STD"/>
    </sliver_type>
    <hardware_type name="rs620"/>
    <interface client_id="node-5:interface-5" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc69:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73877" mac_address="000f530df9d0">
      <ip address="10.10.1.6" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="pc69.cloudlab.umass.edu" port="22" username="bxqml233"/>
      <emulab:console server="boss.cloudlab.umass.edu"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="echo 'y' | sudo mkfs.ext4 /dev/nvme1n1"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="apt-get install -y cmake git python3-pip"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="pc69" hardware_type="rs620"/>
    <host name="node-5.ExpDevena.ds22-PG0.cloudlab.umass.edu" ipv4="198.22.255.80"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-6" exclusive="true" component_manager_id="urn:publicid:IDN+cloudlab.umass.edu+authority+cm" component_id="urn:publicid:IDN+cloudlab.umass.edu+node+pc84" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73866">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+emulab.net+image+emulab-ops//UBUNTU18-64-STD"/>
    </sliver_type>
    <hardware_type name="rs620"/>
    <interface client_id="node-6:interface-6" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc84:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73878" mac_address="000f53231880">
      <ip address="10.10.1.7" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="pc84.cloudlab.umass.edu" port="22" username="bxqml233"/>
      <emulab:console server="boss.cloudlab.umass.edu"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="echo 'y' | sudo mkfs.ext4 /dev/nvme1n1"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="apt-get install -y cmake git python3-pip"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="pc84" hardware_type="rs620"/>
    <host name="node-6.ExpDevena.ds22-PG0.cloudlab.umass.edu" ipv4="198.22.255.95"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-7" exclusive="true" component_manager_id="urn:publicid:IDN+cloudlab.umass.edu+authority+cm" component_id="urn:publicid:IDN+cloudlab.umass.edu+node+pc65" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73868">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+emulab.net+image+emulab-ops//UBUNTU18-64-STD"/>
    </sliver_type>
    <hardware_type name="rs620"/>
    <interface client_id="node-7:interface-7" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc65:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73879" mac_address="000f5322c790">
      <ip address="10.10.1.8" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="pc65.cloudlab.umass.edu" port="22" username="bxqml233"/>
      <emulab:console server="boss.cloudlab.umass.edu"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="echo 'y' | sudo mkfs.ext4 /dev/nvme1n1"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="apt-get install -y cmake git python3-pip"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="pc65" hardware_type="rs620"/>
    <host name="node-7.ExpDevena.ds22-PG0.cloudlab.umass.edu" ipv4="198.22.255.76"/>
  </node>
  <link xmlns:jacks="http://www.protogeni.net/resources/rspec/ext/jacks/1" client_id="link-0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73871" vlantag="2505">
    <interface_ref client_id="node-0:interface-0" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc71:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73872"/>
    <interface_ref client_id="node-1:interface-1" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc82:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73873"/>
    <interface_ref client_id="node-2:interface-2" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc66:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73874"/>
    <interface_ref client_id="node-3:interface-3" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc64:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73875"/>
    <interface_ref client_id="node-4:interface-4" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc70:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73876"/>
    <interface_ref client_id="node-5:interface-5" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc69:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73877"/>
    <interface_ref client_id="node-6:interface-6" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc84:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73878"/>
    <interface_ref client_id="node-7:interface-7" component_id="urn:publicid:IDN+cloudlab.umass.edu+interface+pc65:eth0" sliver_id="urn:publicid:IDN+cloudlab.umass.edu+sliver+73879"/>
    <component_manager name="urn:publicid:IDN+cloudlab.umass.edu+authority+cm"/>
  </link>
  <rspec_tour xmlns="http://www.protogeni.net/resources/rspec/ext/apt-tour/1">
    <description type="markdown">Instantiates 4 nodes of rs620, in ubuntu18.</description>
  </rspec_tour>
  <data_set xmlns="http://www.protogeni.net/resources/rspec/ext/profile-parameters/1">
    <data_item name="emulab.net.parameter.n_nodes">8</data_item>
  </data_set>
  <emulab:portal name="cloudlab" url="https://www.cloudlab.us/status.php?uuid=d316ac2e-1e7d-11ef-9f39-e4434b2381fc" project="ds22" experiment="ExpDevena" sequence="1717071129"/>
  <rs:site_info xmlns:rs="http://www.protogeni.net/resources/rspec/ext/site-info/1">
    <rs:location country="" latitude="42.391890" longitude="-72.526948"/>
  </rs:site_info>
</rspec>

"""
# Parse XML
root = ET.fromstring(xml_content)

# Define namespace
namespace = {
    'xmlns': 'http://www.geni.net/resources/rspec/3',
    'emulab': 'http://www.protogeni.net/resources/rspec/ext/emulab/1'
}

# Extract IPv4 addresses
ipv4_addresses = []

# Iterate through nodes and extract IPv4 addresses
for interface in root.findall('.//xmlns:interface', namespace):
    ipv4_address = interface.find('xmlns:ip', namespace).attrib['address']
    ipv4_addresses.append(ipv4_address)

# Extract IPv4 addresses from host elements
for host in root.findall('.//xmlns:host', namespace):
    ipv4_address = host.attrib['ipv4']
    ipv4_addresses.append(ipv4_address)

# Print the extracted IPv4 addresses
for i in ipv4_addresses[8:]:
    print(i)
# Out:
# 198.22.255.82
# 198.22.255.93
# 198.22.255.77
# 198.22.255.75
# 198.22.255.81
# 198.22.255.80
# 198.22.255.95
# 198.22.255.76

# %%
import re

# Open the file
def extract(file_content):
    # Read each line
    for line in file_content:
        # Use a regular expression to find the hostname
        match = re.search(r'hostname="([^"]*)"', line)
        # If a hostname was found, print it
        if match:
            # print()
            print(f"    <a> {match.group(1)} </a>")

file_content = '''
<rspec xmlns="http://www.geni.net/resources/rspec/3" xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" xmlns:tour="http://www.protogeni.net/resources/rspec/ext/apt-tour/1" xmlns:jacks="http://www.protogeni.net/resources/rspec/ext/jacks/1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.geni.net/resources/rspec/3    http://www.geni.net/resources/rspec/3/request.xsd" type="request">
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-0" exclusive="true" component_manager_id="urn:publicid:IDN+utah.cloudlab.us+authority+cm" component_id="urn:publicid:IDN+utah.cloudlab.us+node+hp190" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817228">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+utah.cloudlab.us+image+ds22-PG0:DrTMH-Enabled-on-xl170"/>
    </sliver_type>
    <hardware_type name="xl170"/>
    <interface client_id="node-0:interface-0" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp190:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817235" mac_address="9cdc715dd571">
      <ip address="10.10.1.1" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="hp190.utah.cloudlab.us" port="22" username="bxqml233"/>
      <emulab:console server="boss.utah.cloudlab.us"/>
      <emulab:recovery available="true"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="sudo apt-get install -y cmake git python3-pip libzmq3-dev libtool-bin"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="hp190" hardware_type="xl170"/>
    <host name="node-0.DrTM-H.ds22-PG0.utah.cloudlab.us" ipv4="128.110.218.229"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-1" exclusive="true" component_manager_id="urn:publicid:IDN+utah.cloudlab.us+authority+cm" component_id="urn:publicid:IDN+utah.cloudlab.us+node+hp187" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817232">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+utah.cloudlab.us+image+ds22-PG0:DrTMH-Enabled-on-xl170"/>
    </sliver_type>
    <hardware_type name="xl170"/>
    <interface client_id="node-1:interface-1" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp187:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817236" mac_address="9cdc715da721">
      <ip address="10.10.1.2" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="hp187.utah.cloudlab.us" port="22" username="bxqml233"/>
      <emulab:console server="boss.utah.cloudlab.us"/>
      <emulab:recovery available="true"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="sudo apt-get install -y cmake git python3-pip libzmq3-dev libtool-bin"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="hp187" hardware_type="xl170"/>
    <host name="node-1.DrTM-H.ds22-PG0.utah.cloudlab.us" ipv4="128.110.218.226"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-2" exclusive="true" component_manager_id="urn:publicid:IDN+utah.cloudlab.us+authority+cm" component_id="urn:publicid:IDN+utah.cloudlab.us+node+hp188" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817225">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+utah.cloudlab.us+image+ds22-PG0:DrTMH-Enabled-on-xl170"/>
    </sliver_type>
    <hardware_type name="xl170"/>
    <interface client_id="node-2:interface-2" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp188:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817237" mac_address="9cdc715d4161">
      <ip address="10.10.1.3" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="hp188.utah.cloudlab.us" port="22" username="bxqml233"/>
      <emulab:console server="boss.utah.cloudlab.us"/>
      <emulab:recovery available="true"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="sudo apt-get install -y cmake git python3-pip libzmq3-dev libtool-bin"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="hp188" hardware_type="xl170"/>
    <host name="node-2.DrTM-H.ds22-PG0.utah.cloudlab.us" ipv4="128.110.218.227"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-3" exclusive="true" component_manager_id="urn:publicid:IDN+utah.cloudlab.us+authority+cm" component_id="urn:publicid:IDN+utah.cloudlab.us+node+hp175" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817226">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+utah.cloudlab.us+image+ds22-PG0:DrTMH-Enabled-on-xl170"/>
    </sliver_type>
    <hardware_type name="xl170"/>
    <interface client_id="node-3:interface-3" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp175:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817238" mac_address="9cdc7156af95">
      <ip address="10.10.1.4" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="hp175.utah.cloudlab.us" port="22" username="bxqml233"/>
      <emulab:console server="boss.utah.cloudlab.us"/>
      <emulab:recovery available="true"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="sudo apt-get install -y cmake git python3-pip libzmq3-dev libtool-bin"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="hp175" hardware_type="xl170"/>
    <host name="node-3.DrTM-H.ds22-PG0.utah.cloudlab.us" ipv4="128.110.218.214"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-4" exclusive="true" component_manager_id="urn:publicid:IDN+utah.cloudlab.us+authority+cm" component_id="urn:publicid:IDN+utah.cloudlab.us+node+hp177" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817229">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+utah.cloudlab.us+image+ds22-PG0:DrTMH-Enabled-on-xl170"/>
    </sliver_type>
    <hardware_type name="xl170"/>
    <interface client_id="node-4:interface-4" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp177:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817239" mac_address="9cdc715d12a1">
      <ip address="10.10.1.5" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="hp177.utah.cloudlab.us" port="22" username="bxqml233"/>
      <emulab:console server="boss.utah.cloudlab.us"/>
      <emulab:recovery available="true"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="sudo apt-get install -y cmake git python3-pip libzmq3-dev libtool-bin"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="hp177" hardware_type="xl170"/>
    <host name="node-4.DrTM-H.ds22-PG0.utah.cloudlab.us" ipv4="128.110.218.216"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-5" exclusive="true" component_manager_id="urn:publicid:IDN+utah.cloudlab.us+authority+cm" component_id="urn:publicid:IDN+utah.cloudlab.us+node+hp176" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817227">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+utah.cloudlab.us+image+ds22-PG0:DrTMH-Enabled-on-xl170"/>
    </sliver_type>
    <hardware_type name="xl170"/>
    <interface client_id="node-5:interface-5" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp176:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817240" mac_address="9cdc7156af65">
      <ip address="10.10.1.6" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="hp176.utah.cloudlab.us" port="22" username="bxqml233"/>
      <emulab:console server="boss.utah.cloudlab.us"/>
      <emulab:recovery available="true"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="sudo apt-get install -y cmake git python3-pip libzmq3-dev libtool-bin"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="hp176" hardware_type="xl170"/>
    <host name="node-5.DrTM-H.ds22-PG0.utah.cloudlab.us" ipv4="128.110.218.215"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-6" exclusive="true" component_manager_id="urn:publicid:IDN+utah.cloudlab.us+authority+cm" component_id="urn:publicid:IDN+utah.cloudlab.us+node+hp198" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817230">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+utah.cloudlab.us+image+ds22-PG0:DrTMH-Enabled-on-xl170"/>
    </sliver_type>
    <hardware_type name="xl170"/>
    <interface client_id="node-6:interface-6" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp198:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817241" mac_address="9cdc7149a891">
      <ip address="10.10.1.7" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="hp198.utah.cloudlab.us" port="22" username="bxqml233"/>
      <emulab:console server="boss.utah.cloudlab.us"/>
      <emulab:recovery available="true"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="sudo apt-get install -y cmake git python3-pip libzmq3-dev libtool-bin"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="hp198" hardware_type="xl170"/>
    <host name="node-6.DrTM-H.ds22-PG0.utah.cloudlab.us" ipv4="128.110.218.237"/>
  </node>
  <node xmlns:emulab="http://www.protogeni.net/resources/rspec/ext/emulab/1" client_id="node-7" exclusive="true" component_manager_id="urn:publicid:IDN+utah.cloudlab.us+authority+cm" component_id="urn:publicid:IDN+utah.cloudlab.us+node+hp167" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817231">
    <sliver_type name="raw-pc">
      <disk_image name="urn:publicid:IDN+utah.cloudlab.us+image+ds22-PG0:DrTMH-Enabled-on-xl170"/>
    </sliver_type>
    <hardware_type name="xl170"/>
    <interface client_id="node-7:interface-7" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp167:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817242" mac_address="9cdc715c8fd1">
      <ip address="10.10.1.8" type="ipv4" netmask="255.255.255.0"/>
    </interface>
    <services>
      <login authentication="ssh-keys" hostname="hp167.utah.cloudlab.us" port="22" username="bxqml233"/>
      <emulab:console server="boss.utah.cloudlab.us"/>
      <emulab:recovery available="true"/>
      <emulab:powercycle available="true"/>
      <emulab:imageable available="true"/>
      <execute shell="/bin/sh" command="sudo apt-get update"/>
      <execute shell="/bin/sh" command="sudo apt-get install -y cmake git python3-pip libzmq3-dev libtool-bin"/>
    </services>
    <emulab:rootkey private="true" public="true"/>
    <emulab:vnode name="hp167" hardware_type="xl170"/>
    <host name="node-7.DrTM-H.ds22-PG0.utah.cloudlab.us" ipv4="128.110.218.206"/>
  </node>
  <link xmlns:jacks="http://www.protogeni.net/resources/rspec/ext/jacks/1" client_id="link-0" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817234" vlantag="274">
    <interface_ref client_id="node-0:interface-0" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp190:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817235"/>
    <interface_ref client_id="node-1:interface-1" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp187:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817236"/>
    <interface_ref client_id="node-2:interface-2" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp188:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817237"/>
    <interface_ref client_id="node-3:interface-3" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp175:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817238"/>
    <interface_ref client_id="node-4:interface-4" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp177:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817239"/>
    <interface_ref client_id="node-5:interface-5" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp176:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817240"/>
    <interface_ref client_id="node-6:interface-6" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp198:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817241"/>
    <interface_ref client_id="node-7:interface-7" component_id="urn:publicid:IDN+utah.cloudlab.us+interface+hp167:eth1" sliver_id="urn:publicid:IDN+utah.cloudlab.us+sliver+1817242"/>
    <component_manager name="urn:publicid:IDN+utah.cloudlab.us+authority+cm"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-0:interface-0" dest_id="node-1:interface-1" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-0:interface-0" dest_id="node-2:interface-2" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-0:interface-0" dest_id="node-3:interface-3" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-0:interface-0" dest_id="node-4:interface-4" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-0:interface-0" dest_id="node-5:interface-5" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-0:interface-0" dest_id="node-6:interface-6" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-0:interface-0" dest_id="node-7:interface-7" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-1:interface-1" dest_id="node-0:interface-0" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-1:interface-1" dest_id="node-2:interface-2" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-1:interface-1" dest_id="node-3:interface-3" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-1:interface-1" dest_id="node-4:interface-4" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-1:interface-1" dest_id="node-5:interface-5" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-1:interface-1" dest_id="node-6:interface-6" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-1:interface-1" dest_id="node-7:interface-7" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-2:interface-2" dest_id="node-0:interface-0" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-2:interface-2" dest_id="node-1:interface-1" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-2:interface-2" dest_id="node-3:interface-3" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-2:interface-2" dest_id="node-4:interface-4" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-2:interface-2" dest_id="node-5:interface-5" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-2:interface-2" dest_id="node-6:interface-6" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-2:interface-2" dest_id="node-7:interface-7" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-3:interface-3" dest_id="node-0:interface-0" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-3:interface-3" dest_id="node-1:interface-1" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-3:interface-3" dest_id="node-2:interface-2" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-3:interface-3" dest_id="node-4:interface-4" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-3:interface-3" dest_id="node-5:interface-5" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-3:interface-3" dest_id="node-6:interface-6" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-3:interface-3" dest_id="node-7:interface-7" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-4:interface-4" dest_id="node-0:interface-0" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-4:interface-4" dest_id="node-1:interface-1" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-4:interface-4" dest_id="node-2:interface-2" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-4:interface-4" dest_id="node-3:interface-3" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-4:interface-4" dest_id="node-5:interface-5" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-4:interface-4" dest_id="node-6:interface-6" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-4:interface-4" dest_id="node-7:interface-7" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-5:interface-5" dest_id="node-0:interface-0" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-5:interface-5" dest_id="node-1:interface-1" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-5:interface-5" dest_id="node-2:interface-2" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-5:interface-5" dest_id="node-3:interface-3" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-5:interface-5" dest_id="node-4:interface-4" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-5:interface-5" dest_id="node-6:interface-6" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-5:interface-5" dest_id="node-7:interface-7" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-6:interface-6" dest_id="node-0:interface-0" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-6:interface-6" dest_id="node-1:interface-1" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-6:interface-6" dest_id="node-2:interface-2" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-6:interface-6" dest_id="node-3:interface-3" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-6:interface-6" dest_id="node-4:interface-4" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-6:interface-6" dest_id="node-5:interface-5" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-6:interface-6" dest_id="node-7:interface-7" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-7:interface-7" dest_id="node-0:interface-0" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-7:interface-7" dest_id="node-1:interface-1" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-7:interface-7" dest_id="node-2:interface-2" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-7:interface-7" dest_id="node-3:interface-3" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-7:interface-7" dest_id="node-4:interface-4" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-7:interface-7" dest_id="node-5:interface-5" capacity="25000000"/>
    <property xmlns="http://www.geni.net/resources/rspec/3" source_id="node-7:interface-7" dest_id="node-6:interface-6" capacity="25000000"/>
  </link>
  <rspec_tour xmlns="http://www.protogeni.net/resources/rspec/ext/apt-tour/1">
    <description type="markdown">8 xl170 with ConnectX4 NIC connected to test RDMA traffic (used for server-client architecture)</description>
  </rspec_tour>
  <data_set xmlns="http://www.protogeni.net/resources/rspec/ext/profile-parameters/1">
    <data_item name="emulab.net.parameter.n_nodes">8</data_item>
  </data_set>
  <emulab:portal name="cloudlab" url="https://www.cloudlab.us/status.php?uuid=49aa29c7-2e14-11ef-9f39-e4434b2381fc" project="ds22" experiment="DrTM-H" sequence="1718785019"/>
  <rs:site_info xmlns:rs="http://www.protogeni.net/resources/rspec/ext/site-info/1">
    <rs:location country="US" latitude="40.750714" longitude="-111.893288"/>
  </rs:site_info>
</rspec>

'''
extract(file_content.split('\n'))
# Out:
#     <a> hp190.utah.cloudlab.us </a>
#     <a> hp187.utah.cloudlab.us </a>
#     <a> hp188.utah.cloudlab.us </a>
#     <a> hp175.utah.cloudlab.us </a>
#     <a> hp177.utah.cloudlab.us </a>
#     <a> hp176.utah.cloudlab.us </a>
#     <a> hp198.utah.cloudlab.us </a>
#     <a> hp167.utah.cloudlab.us </a>
